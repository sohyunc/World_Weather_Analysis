# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 592

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0c841f596853ad356bfef3fbdef08cd8

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cali
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | alyangula
# Processing Record 5 of Set 1 | deputatskiy
# Processing Record 6 of Set 1 | carballo
# Processing Record 7 of Set 1 | anantapur
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | morro bay
# Processing Record 10 of Set 1 | whyalla
# Processing Record 11 of Set 1 | nanzhang
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | saldanha
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | svetlogorsk
# Processing Record 22 of Set 1 | plettenberg bay
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | joao pinheiro
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | meulaboh
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | westerland
# Processing Record 39 of Set 1 | san cristobal
# Processing Record 40 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | terney
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | nome
# Processing Record 45 of Set 1 | mackay
# Processing Record 46 of Set 1 | tuatapere
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | mount isa
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | asau
# Processing Record 6 of Set 2 | si bun ruang
# Processing Record 7 of Set 2 | srednekolymsk
# Processing Record 8 of Set 2 | canoinhas
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | chapais
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | belgrade
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 17 of Set 2 | katsuura
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | vanavara
# Processing Record 20 of Set 2 | pinehurst
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | helmsdale
# Processing Record 23 of Set 2 | begun
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | noyon
# Processing Record 27 of Set 2 | rio cuarto
# Processing Record 28 of Set 2 | cocorit
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | shakawe
# Processing Record 32 of Set 2 | matara
# Processing Record 33 of Set 2 | saint-louis
# Processing Record 34 of Set 2 | mehamn
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | kahului
# Processing Record 37 of Set 2 | jarjis
# City not found. Skipping...
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | uyuni
# Processing Record 40 of Set 2 | flin flon
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | boa vista
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 46 of Set 2 | mayna
# Processing Record 47 of Set 2 | sabana de torres
# Processing Record 48 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | legnago
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | la ronge
# Processing Record 6 of Set 3 | nanakuli
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | bandarbeyla
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | margate
# Processing Record 12 of Set 3 | melendugno
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | cavalcante
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | kyren
# Processing Record 18 of Set 3 | moron
# Processing Record 19 of Set 3 | san pedro
# Processing Record 20 of Set 3 | constitucion
# Processing Record 21 of Set 3 | sobolevo
# Processing Record 22 of Set 3 | waipawa
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | angleton
# Processing Record 25 of Set 3 | new smyrna beach
# Processing Record 26 of Set 3 | kunnamangalam
# Processing Record 27 of Set 3 | takoradi
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | aripuana
# Processing Record 30 of Set 3 | genthin
# Processing Record 31 of Set 3 | sioux lookout
# Processing Record 32 of Set 3 | oussouye
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | albany
# Processing Record 35 of Set 3 | tura
# Processing Record 36 of Set 3 | changji
# Processing Record 37 of Set 3 | sabancuy
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 3 | riyadh
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | gigmoto
# Processing Record 43 of Set 3 | narsaq
# Processing Record 44 of Set 3 | shanghai
# Processing Record 45 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 3 | zhanaozen
# Processing Record 47 of Set 3 | kailua
# Processing Record 48 of Set 3 | solnechnyy
# Processing Record 49 of Set 3 | ambulu
# Processing Record 50 of Set 3 | cam ranh
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | xinye
# Processing Record 3 of Set 4 | hilo
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | hermiston
# Processing Record 8 of Set 4 | roald
# Processing Record 9 of Set 4 | san juan
# Processing Record 10 of Set 4 | ballina
# Processing Record 11 of Set 4 | euclides da cunha
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | baykit
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | saskylakh
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | dolores
# Processing Record 20 of Set 4 | perbaungan
# Processing Record 21 of Set 4 | namibe
# Processing Record 22 of Set 4 | tilichiki
# Processing Record 23 of Set 4 | te anau
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | blackwater
# Processing Record 26 of Set 4 | whitianga
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | port-gentil
# Processing Record 29 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 30 of Set 4 | hofn
# Processing Record 31 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | nemuro
# Processing Record 36 of Set 4 | anloga
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | hay river
# Processing Record 39 of Set 4 | tateyama
# Processing Record 40 of Set 4 | deori khas
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | oranjemund
# Processing Record 43 of Set 4 | ekpoma
# Processing Record 44 of Set 4 | port hedland
# Processing Record 45 of Set 4 | najran
# Processing Record 46 of Set 4 | puerto ayora
# Processing Record 47 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 4 | cordoba
# Processing Record 49 of Set 4 | los andes
# Processing Record 50 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 5 | bambanglipuro
# Processing Record 2 of Set 5 | kochevo
# Processing Record 3 of Set 5 | elizabeth city
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | xining
# Processing Record 6 of Set 5 | tessalit
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | necochea
# Processing Record 9 of Set 5 | tiarei
# Processing Record 10 of Set 5 | lodwar
# Processing Record 11 of Set 5 | ust-barguzin
# Processing Record 12 of Set 5 | pihuamo
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | jacareacanga
# Processing Record 15 of Set 5 | manokwari
# Processing Record 16 of Set 5 | davila
# Processing Record 17 of Set 5 | yar-sale
# Processing Record 18 of Set 5 | cidreira
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | berlevag
# Processing Record 21 of Set 5 | tatawin
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | pudozh
# Processing Record 26 of Set 5 | ust-ishim
# Processing Record 27 of Set 5 | nelson bay
# Processing Record 28 of Set 5 | westport
# Processing Record 29 of Set 5 | mapiripan
# Processing Record 30 of Set 5 | nyurba
# Processing Record 31 of Set 5 | ushirombo
# Processing Record 32 of Set 5 | pevek
# Processing Record 33 of Set 5 | ambilobe
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | roma
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | eten
# Processing Record 38 of Set 5 | sinop
# Processing Record 39 of Set 5 | inhambane
# Processing Record 40 of Set 5 | kaele
# Processing Record 41 of Set 5 | severo-kurilsk
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | floriano
# Processing Record 44 of Set 5 | walvis bay
# Processing Record 45 of Set 5 | isangel
# Processing Record 46 of Set 5 | jumla
# Processing Record 47 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | jahanabad
# Processing Record 50 of Set 5 | poum
# Processing Record 1 of Set 6 | eureka
# Processing Record 2 of Set 6 | mackenzie
# Processing Record 3 of Set 6 | sanmenxia
# Processing Record 4 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 6 | huron
# Processing Record 6 of Set 6 | leningradskiy
# Processing Record 7 of Set 6 | cabo san lucas
# Processing Record 8 of Set 6 | tomatlan
# Processing Record 9 of Set 6 | kudahuvadhoo
# Processing Record 10 of Set 6 | acari
# Processing Record 11 of Set 6 | soyo
# Processing Record 12 of Set 6 | warrington
# Processing Record 13 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 6 | jacqueville
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | berdigestyakh
# Processing Record 17 of Set 6 | murgab
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | san antonio
# Processing Record 20 of Set 6 | purpe
# Processing Record 21 of Set 6 | marathon
# Processing Record 22 of Set 6 | biak
# Processing Record 23 of Set 6 | mastic beach
# Processing Record 24 of Set 6 | soe
# Processing Record 25 of Set 6 | annau
# Processing Record 26 of Set 6 | ulladulla
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | fare
# Processing Record 29 of Set 6 | machala
# Processing Record 30 of Set 6 | ishigaki
# Processing Record 31 of Set 6 | hambantota
# Processing Record 32 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 6 | tautira
# Processing Record 34 of Set 6 | birin
# Processing Record 35 of Set 6 | kayankulam
# Processing Record 36 of Set 6 | maua
# Processing Record 37 of Set 6 | charters towers
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | boo
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | mragowo
# Processing Record 42 of Set 6 | anastacio
# Processing Record 43 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 6 | balsas
# Processing Record 45 of Set 6 | montes claros
# Processing Record 46 of Set 6 | kalmunai
# Processing Record 47 of Set 6 | kapiri mposhi
# Processing Record 48 of Set 6 | avera
# Processing Record 49 of Set 6 | ola
# Processing Record 50 of Set 6 | yatou
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | sorong
# Processing Record 3 of Set 7 | chumikan
# Processing Record 4 of Set 7 | hobyo
# Processing Record 5 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 7 | yulara
# Processing Record 7 of Set 7 | high rock
# Processing Record 8 of Set 7 | bima
# Processing Record 9 of Set 7 | kavaratti
# Processing Record 10 of Set 7 | turayf
# Processing Record 11 of Set 7 | rafaela
# Processing Record 12 of Set 7 | santa isabel do rio negro
# Processing Record 13 of Set 7 | cartagena
# Processing Record 14 of Set 7 | kailasahar
# City not found. Skipping...
# Processing Record 15 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 7 | praya
# Processing Record 17 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 7 | beira
# Processing Record 19 of Set 7 | tra vinh
# Processing Record 20 of Set 7 | waingapu
# Processing Record 21 of Set 7 | kralendijk
# Processing Record 22 of Set 7 | abadiania
# Processing Record 23 of Set 7 | caravelas
# Processing Record 24 of Set 7 | sept-iles
# Processing Record 25 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 7 | lengshuijiang
# Processing Record 27 of Set 7 | gorodishche
# Processing Record 28 of Set 7 | auki
# Processing Record 29 of Set 7 | victor harbor
# Processing Record 30 of Set 7 | ust-kuyga
# Processing Record 31 of Set 7 | banda aceh
# Processing Record 32 of Set 7 | vila franca do campo
# Processing Record 33 of Set 7 | kortkeros
# Processing Record 34 of Set 7 | birao
# Processing Record 35 of Set 7 | arang
# Processing Record 36 of Set 7 | lake charles
# Processing Record 37 of Set 7 | chara
# Processing Record 38 of Set 7 | ust-tarka
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | palmer
# Processing Record 41 of Set 7 | andenes
# Processing Record 42 of Set 7 | lakes entrance
# Processing Record 43 of Set 7 | bonavista
# Processing Record 44 of Set 7 | kavieng
# Processing Record 45 of Set 7 | ketchikan
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | nouakchott
# Processing Record 48 of Set 7 | lavrentiya
# Processing Record 49 of Set 7 | laguna
# Processing Record 50 of Set 7 | iquitos
# Processing Record 1 of Set 8 | noumea
# Processing Record 2 of Set 8 | baoro
# Processing Record 3 of Set 8 | constantine
# Processing Record 4 of Set 8 | kirakira
# Processing Record 5 of Set 8 | daru
# Processing Record 6 of Set 8 | anadyr
# Processing Record 7 of Set 8 | derzhavinsk
# Processing Record 8 of Set 8 | marmaron
# City not found. Skipping...
# Processing Record 9 of Set 8 | jerantut
# Processing Record 10 of Set 8 | gopalur
# Processing Record 11 of Set 8 | tondano
# Processing Record 12 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 8 | ciochina
# Processing Record 14 of Set 8 | bereda
# Processing Record 15 of Set 8 | port lincoln
# Processing Record 16 of Set 8 | teguise
# Processing Record 17 of Set 8 | chitral
# Processing Record 18 of Set 8 | laredo
# Processing Record 19 of Set 8 | villa bruzual
# Processing Record 20 of Set 8 | chicama
# Processing Record 21 of Set 8 | manzhouli
# Processing Record 22 of Set 8 | badiraguato
# Processing Record 23 of Set 8 | hualmay
# Processing Record 24 of Set 8 | west wendover
# Processing Record 25 of Set 8 | bayir
# Processing Record 26 of Set 8 | gunjur
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | fethiye
# Processing Record 29 of Set 8 | santa rosa
# Processing Record 30 of Set 8 | strzelce krajenskie
# Processing Record 31 of Set 8 | sharan
# Processing Record 32 of Set 8 | kaeo
# Processing Record 33 of Set 8 | binghamton
# Processing Record 34 of Set 8 | batagay-alyta
# Processing Record 35 of Set 8 | amalapuram
# Processing Record 36 of Set 8 | majene
# Processing Record 37 of Set 8 | gao
# Processing Record 38 of Set 8 | ribas do rio pardo
# Processing Record 39 of Set 8 | camocim
# Processing Record 40 of Set 8 | porto walter
# Processing Record 41 of Set 8 | sibu
# Processing Record 42 of Set 8 | mahebourg
# Processing Record 43 of Set 8 | klaksvik
# Processing Record 44 of Set 8 | joshimath
# Processing Record 45 of Set 8 | suntar
# Processing Record 46 of Set 8 | wakkanai
# Processing Record 47 of Set 8 | maputo
# Processing Record 48 of Set 8 | grand-santi
# Processing Record 49 of Set 8 | tambovka
# Processing Record 50 of Set 8 | shirokiy
# Processing Record 1 of Set 9 | arman
# Processing Record 2 of Set 9 | husavik
# Processing Record 3 of Set 9 | guerrero negro
# Processing Record 4 of Set 9 | chokurdakh
# Processing Record 5 of Set 9 | luanda
# Processing Record 6 of Set 9 | duluth
# Processing Record 7 of Set 9 | la plata
# Processing Record 8 of Set 9 | morondava
# Processing Record 9 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 9 | kaminskiy
# Processing Record 11 of Set 9 | hays
# Processing Record 12 of Set 9 | waddan
# Processing Record 13 of Set 9 | vila velha
# Processing Record 14 of Set 9 | the valley
# Processing Record 15 of Set 9 | maniitsoq
# Processing Record 16 of Set 9 | airai
# Processing Record 17 of Set 9 | satipo
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | muravlenko
# Processing Record 20 of Set 9 | panaba
# Processing Record 21 of Set 9 | kloulklubed
# Processing Record 22 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 9 | egvekinot
# Processing Record 24 of Set 9 | coihaique
# Processing Record 25 of Set 9 | samarai
# Processing Record 26 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 9 | opuwo
# Processing Record 28 of Set 9 | bahile
# Processing Record 29 of Set 9 | kununurra
# Processing Record 30 of Set 9 | harer
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | sabang
# Processing Record 33 of Set 9 | bara
# Processing Record 34 of Set 9 | belmonte
# Processing Record 35 of Set 9 | badarganj
# Processing Record 36 of Set 9 | puerto escondido
# Processing Record 37 of Set 9 | ridgecrest
# Processing Record 38 of Set 9 | huarmey
# Processing Record 39 of Set 9 | tromso
# Processing Record 40 of Set 9 | albanel
# Processing Record 41 of Set 9 | aksu
# Processing Record 42 of Set 9 | enterprise
# Processing Record 43 of Set 9 | malangali
# Processing Record 44 of Set 9 | sosnovo-ozerskoye
# Processing Record 45 of Set 9 | saint-augustin
# Processing Record 46 of Set 9 | stancuta
# Processing Record 47 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 9 | goya
# Processing Record 49 of Set 9 | zavet
# Processing Record 50 of Set 9 | tabou
# Processing Record 1 of Set 10 | sao joao da barra
# Processing Record 2 of Set 10 | awjilah
# Processing Record 3 of Set 10 | horsham
# Processing Record 4 of Set 10 | nereju
# Processing Record 5 of Set 10 | pandan
# Processing Record 6 of Set 10 | college
# Processing Record 7 of Set 10 | leshukonskoye
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | mosquera
# Processing Record 10 of Set 10 | mahanoro
# Processing Record 11 of Set 10 | morant bay
# Processing Record 12 of Set 10 | bathsheba
# Processing Record 13 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 10 | broome
# Processing Record 15 of Set 10 | zarautz
# Processing Record 16 of Set 10 | lata
# Processing Record 17 of Set 10 | odienne
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | santander
# Processing Record 20 of Set 10 | tual
# Processing Record 21 of Set 10 | montrose
# Processing Record 22 of Set 10 | mandera
# Processing Record 23 of Set 10 | azad shahr
# Processing Record 24 of Set 10 | krasnoselkup
# Processing Record 25 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 10 | nizwa
# Processing Record 27 of Set 10 | shingu
# Processing Record 28 of Set 10 | taylor
# Processing Record 29 of Set 10 | touros
# Processing Record 30 of Set 10 | miri
# Processing Record 31 of Set 10 | burayevo
# Processing Record 32 of Set 10 | broken hill
# Processing Record 33 of Set 10 | pyay
# Processing Record 34 of Set 10 | camacupa
# Processing Record 35 of Set 10 | port-cartier
# Processing Record 36 of Set 10 | ponta delgada
# Processing Record 37 of Set 10 | pahrump
# Processing Record 38 of Set 10 | khorixas
# Processing Record 39 of Set 10 | preobrazheniye
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | impfondo
# Processing Record 42 of Set 10 | ostrovnoy
# Processing Record 43 of Set 10 | penzance
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | belfast
# Processing Record 46 of Set 10 | ukiah
# Processing Record 47 of Set 10 | paamiut
# Processing Record 48 of Set 10 | odweyne
# Processing Record 49 of Set 10 | jaffna
# Processing Record 50 of Set 10 | houma
# Processing Record 1 of Set 11 | upata
# Processing Record 2 of Set 11 | yichang
# Processing Record 3 of Set 11 | magdalena
# Processing Record 4 of Set 11 | muswellbrook
# Processing Record 5 of Set 11 | padang
# Processing Record 6 of Set 11 | pochutla
# Processing Record 7 of Set 11 | fuerte olimpo
# Processing Record 8 of Set 11 | middlebury
# Processing Record 9 of Set 11 | oriximina
# Processing Record 10 of Set 11 | camana
# Processing Record 11 of Set 11 | virginia beach
# Processing Record 12 of Set 11 | skibbereen
# Processing Record 13 of Set 11 | ermoupolis
# Processing Record 14 of Set 11 | karratha
# Processing Record 15 of Set 11 | burley
# Processing Record 16 of Set 11 | saint-georges
# Processing Record 17 of Set 11 | mopipi
# Processing Record 18 of Set 11 | kontagora
# Processing Record 19 of Set 11 | pangkalanbuun
# Processing Record 20 of Set 11 | amapa
# Processing Record 21 of Set 11 | abu samrah
# Processing Record 22 of Set 11 | ipora
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | eirunepe
# Processing Record 25 of Set 11 | saint john
# Processing Record 26 of Set 11 | beringovskiy
# Processing Record 27 of Set 11 | deep river
# Processing Record 28 of Set 11 | cayenne
# Processing Record 29 of Set 11 | labuhan
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | pedernales
# Processing Record 32 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 11 | umm lajj
# Processing Record 34 of Set 11 | altay
# Processing Record 35 of Set 11 | rocha
# Processing Record 36 of Set 11 | hastings
# Processing Record 37 of Set 11 | comodoro rivadavia
# Processing Record 38 of Set 11 | salym
# Processing Record 39 of Set 11 | nioro
# Processing Record 40 of Set 11 | lorengau
# Processing Record 41 of Set 11 | shelburne
# Processing Record 42 of Set 11 | batemans bay
# Processing Record 43 of Set 11 | namatanai
# Processing Record 44 of Set 11 | san carlos
# Processing Record 45 of Set 11 | bellinzona
# Processing Record 46 of Set 11 | codrington
# Processing Record 47 of Set 11 | wajima
# Processing Record 48 of Set 11 | chake chake
# Processing Record 49 of Set 11 | pafos
# Processing Record 50 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 1 of Set 12 | cockburn town
# Processing Record 2 of Set 12 | aleksandrovka
# Processing Record 3 of Set 12 | puerto colombia
# Processing Record 4 of Set 12 | bud
# Processing Record 5 of Set 12 | nueve de julio
# Processing Record 6 of Set 12 | taxco
# Processing Record 7 of Set 12 | nyuksenitsa
# Processing Record 8 of Set 12 | okhotsk
# Processing Record 9 of Set 12 | katherine
# Processing Record 10 of Set 12 | humaita
# Processing Record 11 of Set 12 | bansang
# Processing Record 12 of Set 12 | peniche
# Processing Record 13 of Set 12 | chernyshkovskiy
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | san quintin
# Processing Record 16 of Set 12 | nizhnyaya tavda
# Processing Record 17 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 18 of Set 12 | sri aman
# Processing Record 19 of Set 12 | ritchie
# Processing Record 20 of Set 12 | launceston
# Processing Record 21 of Set 12 | dubai
# Processing Record 22 of Set 12 | bonfim
# Processing Record 23 of Set 12 | russell
# Processing Record 24 of Set 12 | madikeri
# Processing Record 25 of Set 12 | pizhanka
# Processing Record 26 of Set 12 | blythe
# Processing Record 27 of Set 12 | boden
# Processing Record 28 of Set 12 | springfield
# Processing Record 29 of Set 12 | lockhart
# Processing Record 30 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 12 | zhangye
# Processing Record 32 of Set 12 | valparaiso
# Processing Record 33 of Set 12 | goderich
# Processing Record 34 of Set 12 | laje
# Processing Record 35 of Set 12 | cedar city
# Processing Record 36 of Set 12 | lasa
# Processing Record 37 of Set 12 | qinzhou
# Processing Record 38 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 39 of Set 12 | atar
# Processing Record 40 of Set 12 | yaan
# Processing Record 41 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 12 | clyde river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 545

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Cali   3.4372  -76.5225     77.00        73          75
# 1          Rikitea -23.1203 -134.9692     79.30        74           2
# 2  Arraial Do Cabo -22.9661  -42.0278     77.81        88          56
# 3        Alyangula -13.8483  136.4192     85.53        67          73
# 4      Deputatskiy  69.3000  139.9000      7.70        89         100
# 5         Carballo  43.2130   -8.6910     55.00        76           0
# 6        Anantapur  14.6833   77.6000     80.01        44          76
# 7          Mataura -46.1927  168.8643     62.01        90          33
# 8        Morro Bay  35.3658 -120.8499     71.60        37           1
# 9          Whyalla -33.0333  137.5833     66.20        68           0
#
#    Wind Speed Country Weather Description
# 0        4.61      CO       broken clouds
# 1       15.55      PF           clear sky
# 2        8.25      BR       broken clouds
# 3       17.34      AU       broken clouds
# 4        2.75      RU     overcast clouds
# 5        3.44      ES           clear sky
# 6        6.22      IN       broken clouds
# 7       10.00      NZ    scattered clouds
# 8       18.41      US           clear sky
# 9        4.61      AU           clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Cali      CO   3.4372  -76.5225     77.00        73          75
# 1          Rikitea      PF -23.1203 -134.9692     79.30        74           2
# 2  Arraial Do Cabo      BR -22.9661  -42.0278     77.81        88          56
# 3        Alyangula      AU -13.8483  136.4192     85.53        67          73
# 4      Deputatskiy      RU  69.3000  139.9000      7.70        89         100
# 5         Carballo      ES  43.2130   -8.6910     55.00        76           0
# 6        Anantapur      IN  14.6833   77.6000     80.01        44          76
# 7          Mataura      NZ -46.1927  168.8643     62.01        90          33
# 8        Morro Bay      US  35.3658 -120.8499     71.60        37           1
# 9          Whyalla      AU -33.0333  137.5833     66.20        68           0
#
#    Wind Speed Weather Description
# 0        4.61       broken clouds
# 1       15.55           clear sky
# 2        8.25       broken clouds
# 3       17.34       broken clouds
# 4        2.75     overcast clouds
# 5        3.44           clear sky
# 6        6.22       broken clouds
# 7       10.00    scattered clouds
# 8       18.41           clear sky
# 9        4.61           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
